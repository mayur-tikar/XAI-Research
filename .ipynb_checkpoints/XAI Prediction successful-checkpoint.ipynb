# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt

# %%
# Load financial time series data from a CSV file
data = pd.read_csv('AAPL_2006-01-01_to_2018-01-01.csv')
data['Date'] = pd.to_datetime(data['Date'])
data.set_index('Date', inplace=True)

# %%
# Prepare the dataset
prices = data['Close'].values.reshape(-1, 1)
scaler = MinMaxScaler()
scaled_prices = scaler.fit_transform(prices)

# %%
# Split the data into train and test sets
train_size = int(len(scaled_prices) * 0.8)
train_data, test_data = scaled_prices[:train_size], scaled_prices[train_size:]

# %%
# Create sequences for input and output
def create_sequences(data, seq_length):
    sequences = []
    for i in range(len(data) - seq_length):
        seq = data[i:i+seq_length]
        target = data[i+seq_length]
        sequences.append((seq, target))
    return sequences

seq_length = 10
train_sequences = create_sequences(train_data, seq_length)
test_sequences = create_sequences(test_data, seq_length)

X_train, y_train = np.array([seq for seq, target in train_sequences]), np.array([target for seq, target in train_sequences])
X_test, y_test = np.array([seq for seq, target in test_sequences]), np.array([target for seq, target in test_sequences])

# %%
# Build and train an LSTM model
model = tf.keras.Sequential([
    tf.keras.layers.LSTM(64, activation='relu', input_shape=(seq_length, 1)),
    tf.keras.layers.Dense(1)
])

model.compile(optimizer='adam', loss='mse')
model.fit(X_train, y_train, epochs=20, batch_size=32, validation_data=(X_test, y_test))
# Out:
# Epoch 1/20
# 76/76 [==============================] - 1s 3ms/step - loss: 0.0180 - val_loss: 0.0017
# Epoch 2/20
# 76/76 [==============================] - 0s 2ms/step - loss: 1.5141e-04 - val_loss: 7.1814e-04
# Epoch 3/20
# 76/76 [==============================] - 0s 2ms/step - loss: 1.0361e-04 - val_loss: 3.7368e-04
# Epoch 4/20
# 76/76 [==============================] - 0s 2ms/step - loss: 1.0362e-04 - val_loss: 3.6722e-04
# Epoch 5/20
# 76/76 [==============================] - 0s 2ms/step - loss: 9.9434e-05 - val_loss: 4.0354e-04
# Epoch 6/20
# 76/76 [==============================] - 0s 2ms/step - loss: 1.0365e-04 - val_loss: 3.2175e-04
# Epoch 7/20
# 76/76 [==============================] - 0s 2ms/step - loss: 9.7144e-05 - val_loss: 3.1948e-04
# Epoch 8/20
# 76/76 [==============================] - 0s 2ms/step - loss: 1.0189e-04 - val_loss: 3.1463e-04
# Epoch 9/20
# 76/76 [==============================] - 0s 2ms/step - loss: 1.0597e-04 - val_loss: 3.1829e-04
# Epoch 10/20
# 76/76 [==============================] - 0s 2ms/step - loss: 9.6707e-05 - val_loss: 3.0066e-04
# Epoch 11/20
# 76/76 [==============================] - 0s 2ms/step - loss: 9.6239e-05 - val_loss: 3.3832e-04
# Epoch 12/20
# 76/76 [==============================] - 0s 2ms/step - loss: 9.3399e-05 - val_loss: 4.2549e-04
# Epoch 13/20
# 76/76 [==============================] - 0s 2ms/step - loss: 1.0070e-04 - val_loss: 4.0601e-04
# Epoch 14/20
# 76/76 [==============================] - 0s 2ms/step - loss: 9.7193e-05 - val_loss: 4.4747e-04
# Epoch 15/20
# 76/76 [==============================] - 0s 2ms/step - loss: 1.0287e-04 - val_loss: 3.3545e-04
# Epoch 16/20
# 76/76 [==============================] - 0s 2ms/step - loss: 9.0996e-05 - val_loss: 3.1294e-04
# Epoch 17/20
# 76/76 [==============================] - 0s 2ms/step - loss: 8.8978e-05 - val_loss: 2.6563e-04
# Epoch 18/20
# 76/76 [==============================] - 0s 2ms/step - loss: 8.4283e-05 - val_loss: 3.2545e-04
# Epoch 19/20
# 76/76 [==============================] - 0s 2ms/step - loss: 8.6034e-05 - val_loss: 2.7520e-04
# Epoch 20/20
# 76/76 [==============================] - 0s 2ms/step - loss: 8.4726e-05 - val_loss: 3.1184e-04

# %%
# Make predictions
y_pred = model.predict(X_test)
# Out:
# 19/19 [==============================] - 0s 800us/step

# %%
# Inverse transform predictions to original scale
y_pred_original = scaler.inverse_transform(y_pred)
y_test_original = scaler.inverse_transform(y_test)

# %%
# Plot the predicted vs. actual stock prices
plt.figure(figsize=(12, 6))
plt.plot(data.index[train_size+seq_length:], y_test_original, label='True Prices', lw=3)
plt.plot(data.index[train_size+seq_length:], y_pred_original, label='Predicted Prices', lw=3)
plt.xlabel('Date')
plt.ylabel('Stock Price')
plt.title('Stock Price Prediction using LSTM')
plt.legend()
plt.show()
